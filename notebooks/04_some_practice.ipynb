# %%
import numpy as np

# %%
arr = np.array([5, 12, 7, 3, 18, 10, 2, 15])

print("Mean:", np.mean(arr))
print("Median:", np.median(arr))
print("Std Dev:", np.std(arr))
print("Max:", np.max(arr))
print("Min:", np.min(arr))

print("\nSorted:", np.sort(arr))

print("\nValues > 10:", arr[arr > 10])

print("\nArray * 3:", arr * 3)

print("\nReplace <5 with 0:", np.where(arr < 5, 0, arr))
# Out:
# Mean: 9.0
# Median: 8.5
# Std Dev: 5.385164807134504
# Max: 18
# Min: 2
#
# Sorted: [ 2  3  5  7 10 12 15 18]
#
# Values > 10: [12 18 15]
#
# Array * 3: [15 36 21  9 54 30  6 45]
#
# Replace <5 with 0: [ 5 12  7  0 18 10  0 15]

# %%
scores = np.array([
    [85, 78, 92],
    [70, 88, 80],
    [90, 91, 85],
    [60, 65, 70],
    [88, 84, 91]
])
